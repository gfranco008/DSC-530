# %% [markdown]
# <a href="https://colab.research.google.com/github/gfranco008/DSC-530/blob/master/States_Class_Activity_Week03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium
# Out:
# ...
#      |████████████████████████████████| 93 kB 2.5 MB/s eta 0:00:011
# ...

# %%
import pandas as pd
import folium
import json

# %%
### (1) read covid data from NYT
db = "https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv"
df = pd.read_csv(db)

# %%
# 2 (A) filter by date
# 2 (B) group by state name, and sum the cases numbers of all the counties of each state
def covid_stat_on(df,strDate):
    df_temp = df[df['date']==strDate][['state','cases','deaths']].groupby('state',as_index = False).sum().copy().dropna().reset_index(drop=True)
    return df_temp

# %%
# 3 (A) Load GeoJSON
state_geo_json = 'https://raw.githubusercontent.com/umassdgithub/DataVizFall2020_Colab/master/cb_2018_us_state_20m.json'
df_state_geo_json = pd.read_json(state_geo_json)

df_state_geo_json['features'].iloc[0]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[-76.046213, 38.025532999999996],
#      [-76.04652999999999, 37.953586],
#      [-75.98464799999999, 37.938120999999995],
#      [-75.98008899999999, 38.004891],
#      [-76.00733699999999, 38.036705999999995],
#      [-76.046213, 38.025532999999996]]],
#    [[[-79.47666199999999, 39.721078],
#      [-79.482366, 39.531689],
#      [-79.484372, 39.344300000000004],
#      [-79.486873, 39.205960999999995],
#      [-79.424413, 39.228170999999996],
#      [-79.35374999999999, 39.278039],
#      [-79.283723, 39.30964],
#      [-79.26239211717609, 39.3262438284674],
#      [-79.16649699999999, 39.400887999999995],
#      [-79.091329, 39.472407],
#      [-79.0674474080724, 39.4728086991282],
#      [-79.035623, 39.473344],
#      [-78.956751, 39.440264],
#      [-78.942618, 39.479614],
#      [-78.851016, 39.554044],
#      [-78.77114, 39.638387],
#      [-78.73904999999999, 39.609697],
# ...

# %%
# 3 (B) Make a dictionary of State names and 2 Letter ID using the GeoJSON database
state_abbrv={}
for i in range(len(df_state_geo_json['features'])):
    state_abbrv[df_state_geo_json['features'].iloc[i]['properties']['NAME']] = df_state_geo_json['features'].iloc[i]['properties']['STUSPS']
state_abbrv
# Out:
# {'Maryland': 'MD',
#  'Iowa': 'IA',
#  'Delaware': 'DE',
#  'Ohio': 'OH',
#  'Pennsylvania': 'PA',
#  'Nebraska': 'NE',
#  'Washington': 'WA',
#  'Puerto Rico': 'PR',
#  'Alabama': 'AL',
#  'Arkansas': 'AR',
#  'New Mexico': 'NM',
#  'Texas': 'TX',
#  'California': 'CA',
#  'Kentucky': 'KY',
#  'Georgia': 'GA',
#  'Wisconsin': 'WI',
#  'Oregon': 'OR',
#  'Missouri': 'MO',
#  'Virginia': 'VA',
#  'Tennessee': 'TN',
#  'Louisiana': 'LA',
#  'New York': 'NY',
#  'Michigan': 'MI',
#  'Idaho': 'ID',
#  'Florida': 'FL',
#  'Alaska': 'AK',
#  'Illinois': 'IL',
#  'Montana': 'MT',
#  'Minnesota': 'MN',
#  'Indiana': 'IN',
#  'Massachusetts': 'MA',
#  'Kansas': 'KS',
#  'Nevada': 'NV',
#  'Vermont': 'VT',
#  'Connecticut': 'CT',
#  'New Jersey': 'NJ',
#  'District of Columbia': 'DC',
#  'North Carolina': 'NC',
#  'Utah': 'UT',
#  'North Dakota': 'ND',
#  'South Carolina': 'SC',
#  'Mississippi': 'MS',
#  'Colorado': 'CO',
#  'South Dakota': 'SD',
#  'Oklahoma': 'OK',
#  'Wyoming': 'WY',
# ...

# %%
# 4 Get sample data for 1 day (09/13/2020)
covid_stat = covid_stat_on(df,'2020-09-13')
covid_stat.head(1)
# Out:
#      state   cases  deaths
# 0  Alabama  138755  2351

# %%
state_abbrv.keys()
# Out:
# dict_keys(['Maryland', 'Iowa', 'Delaware', 'Ohio', 'Pennsylvania', 'Nebraska', 'Washington', 'Puerto Rico', 'Alabama', 'Arkansas', 'New Mexico', 'Texas', 'California', 'Kentucky', 'Georgia', 'Wisconsin', 'Oregon', 'Missouri', 'Virginia', 'Tennessee', 'Louisiana', 'New York', 'Michigan', 'Idaho', 'Florida', 'Alaska', 'Illinois', 'Montana', 'Minnesota', 'Indiana', 'Massachusetts', 'Kansas', 'Nevada', 'Vermont', 'Connecticut', 'New Jersey', 'District of Columbia', 'North Carolina', 'Utah', 'North Dakota', 'South Carolina', 'Mississippi', 'Colorado', 'South Dakota', 'Oklahoma', 'Wyoming', 'West Virginia', 'Maine', 'Hawaii', 'New Hampshire', 'Arizona', 'Rhode Island'])

# %%
# Translate state name to state 2 letter code
covid_stat_translated = covid_stat[covid_stat['state'].isin(state_abbrv.keys())].copy()
covid_stat_translated['state'] = covid_stat_translated['state'].apply(lambda x:state_abbrv[x] )

# %%
covid_stat_translated.head()
# Out:
#   state   cases  deaths
# 0  AL    138755  2351
# 1  AK    7136    41
# 2  AZ    208514  5322
# 3  AR    70219   981
# 4  CA    763389  14386

# %%
pd.set_option('display.max_colwidth', -1)

df_state_geo_json.loc[0]
# Out:
# <ipython-input-19-783df1e77a09>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# ...

# %%
## 1) make a folium Map object first
m = folium.Map(
            location=[48, -102], # center the map to this point
            zoom_start=4)        # starting zoom!

# %%
# 2) make a Choropleth layer, and add it to the map object
folium.Choropleth(
    geo_data=state_geo_json, ## load the downloaded GeoJSON (mapshaper.org converted)
    name='Covid-19 Cases',                ## add a name for the layer
    legend_name='Actual Covid-19 Cases',  ## add legend topic
    data=covid_stat_translated,   ## pass our covid-19 data to the layer method
    columns=['state','cases'],             ## the columns from our data
    key_on='feature.properties.STUSPS',    ## the fips code from the downloaded GeoJSON file
    fill_color='BuGn',                    ## color style BuGn, BuPu, GnBu, OrRd, PuBu, PuBuGn, PuRd, RdPu, YlGn, YlGnBu, YlOrBr, and YlOrRd
    bins=4,                               ## number of bins usef of color codding 
    fill_opacity=0.7,
    line_opacity=0.2,
    nan_fill_color='blue',
    highlight=True,
).add_to(m)

choropleth = folium.Choropleth(
    geo_data=state_geo_json, ## load the downloaded GeoJSON (mapshaper.org converted)
    name='Covid-19 Deaths',                ## add a name for the layer
    legend_name='Actual Covid-19 Deaths',  ## add legend topic
    data=covid_stat_translated,   ## pass our covid-19 data to the layer method
    columns=['state','deaths'],             ## the columns from our data
    key_on='feature.properties.STUSPS',    ## the fips code from the downloaded GeoJSON file
    fill_color='RdPu',                    ## color style BuGn, BuPu, GnBu, OrRd, PuBu, PuBuGn, PuRd, RdPu, YlGn, YlGnBu, YlOrBr, and YlOrRd
    bins=4,                               ## number of bins usef of color codding 
    fill_opacity=0.7,
    line_opacity=0.2,
    nan_fill_color='blue',
    highlight=True,
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
[COMPLETE THIS PART.] 
[Download ipynb file upload it into myCoureses]
[upload HTML file (index.html) into your GitHub to make an online interactive map]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('index.html')

# %%
# Out:
# 35.0
